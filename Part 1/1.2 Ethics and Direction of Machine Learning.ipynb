# %% [markdown]
# # 1.2: Ethics and Direction of Machine Learning

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
#Import unscaled test values data set 
df = pd.read_csv('/Users/ariedlin/Desktop/Career Foundry Assignments/Machine Learning/2. Data/Dataset-weather-prediction-dataset-processed.csv')

# %%
#Check head to visualize dataframe
df.head(10)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
# 5  19600106      1                  1               2.1            0.78
# 6  19600107      1                  3               2.1            0.87
# 7  19600108      1                  8               2.1            0.95
# 8  19600109      1                  8               2.1            0.98
# 9  19600110      1                  3               2.1            0.74
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# ...

# %%
#Check basic info about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %%
#Check shape of dataframe
df.shape
# Out:
# (22950, 170)

# %%
#Reset the index for the dataframe
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %% [markdown]
# # Check for Missing Values

# %%
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %% [markdown]
# There are no missing values in the dataframe.

# %% [markdown]
# # Scaling

# %%
#Check column names to find numberic columns
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['id', 'DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_wind_speed', 'BASEL_humidity', 'BASEL_pressure', 'BASEL_global_radiation', 'BASEL_precipitation', 'BASEL_snow_depth', 'BASEL_sunshine', 'BASEL_temp_mean', 'BASEL_temp_min', 'BASEL_temp_max', 'BELGRADE_cloud_cover', 'BELGRADE_humidity', 'BELGRADE_pressure', 'BELGRADE_global_radiation', 'BELGRADE_precipitation', 'BELGRADE_sunshine', 'BELGRADE_temp_mean', 'BELGRADE_temp_min', 'BELGRADE_temp_max', 'BUDAPEST_cloud_cover', 'BUDAPEST_humidity', 'BUDAPEST_pressure', 'BUDAPEST_global_radiation', 'BUDAPEST_precipitation', 'BUDAPEST_sunshine', 'BUDAPEST_temp_mean', 'BUDAPEST_temp_min', 'BUDAPEST_temp_max', 'DEBILT_cloud_cover', 'DEBILT_wind_speed', 'DEBILT_humidity', 'DEBILT_pressure', 'DEBILT_global_radiation', 'DEBILT_precipitation', 'DEBILT_sunshine', 'DEBILT_temp_mean', 'DEBILT_temp_min', 'DEBILT_temp_max', 'DUSSELDORF_cloud_cover', 'DUSSELDORF_wind_speed', 'DUSSELDORF_humidity', 'DUSSELDORF_pressure', 'DUSSELDORF_global_radiation', 'DUSSE
# ...

# %%
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
#Create scaler object using StandardScaler from sklearn.preprocessing

scaler = StandardScaler()

# %%
#Create a new data frame with scaled data

df_scaled = pd.DataFrame(scaler.fit_transform(df))
df_scaled.head()
# Out:
#         0         1         2         3        4         5         6    \
# 0 -1.731975 -1.707663 -1.599964  0.660514 -0.02793  0.826097 -0.001949
# 1 -1.731824 -1.707657 -1.599964  0.244897 -0.02793  0.735760 -0.001949
# 2 -1.731673 -1.707652 -1.599964  1.076130 -0.02793  1.277781 -0.001949
# 3 -1.731523 -1.707646 -1.599964 -1.001953 -0.02793  1.458455 -0.001949
# 4 -1.731372 -1.707641 -1.599964  0.244897 -0.02793  1.729466 -0.001949
#
#         7         8         9    ...       161       162       163       164  \
# 0 -1.101066 -0.265148 -0.179228  ... -0.443701  0.761754 -1.299744 -0.806427
# 1 -1.058108  1.658760 -0.179228  ...  0.783085  1.183580 -1.262455 -1.042055
# 2 -1.251420  0.155707 -0.179228  ...  0.783085  1.183580 -0.432779 -1.136306
# 3 -0.821838 -0.445514 -0.179228  ...  0.783085  0.480538  0.387574 -1.183432
# 4 -0.746661 -0.164944 -0.179228  ... -1.670486 -0.363113  1.729970 -0.794645
#
#         165       166       167       168       169       170
# ...

# %%
# Compare the original vs. scaled data

df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
#Export dataframe as a pickle
df_scaled.to_pickle('/Users/ariedlin/Desktop/Career Foundry Assignments/Machine Learning/2. Data/df_scaled')
